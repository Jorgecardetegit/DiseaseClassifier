# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorgecardetegit/DiseaseClassifier/blob/main/Dataset_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Extracting credentials from the kaggle.json

# %%
from google.colab import files
files.upload()

# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas as pd

od.download(
    "https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: jorgecardete
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 2.04G/2.04G [01:08<00:00, 31.8MB/s]

# %% [markdown]
# For now I will only perform the analysis on the Apple dataset. Based on these results I will consider to train a model to the other datasets and include it on the Fast API.

# %%
# !ls "/content/plantvillage-dataset/plantvillage dataset/color"
# Out:
#  Apple___Apple_scab
#  Apple___Black_rot
#  Apple___Cedar_apple_rust
#  Apple___healthy
#  Blueberry___healthy
# 'Cherry_(including_sour)___healthy'
# 'Cherry_(including_sour)___Powdery_mildew'
# 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'
# 'Corn_(maize)___Common_rust_'
# 'Corn_(maize)___healthy'
# 'Corn_(maize)___Northern_Leaf_Blight'
#  Grape___Black_rot
# 'Grape___Esca_(Black_Measles)'
#  Grape___healthy
# 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'
# 'Orange___Haunglongbing_(Citrus_greening)'
#  Peach___Bacterial_spot
#  Peach___healthy
#  Pepper,_bell___Bacterial_spot
#  Pepper,_bell___healthy
#  Potato___Early_blight
#  Potato___healthy
#  Potato___Late_blight
#  Raspberry___healthy
#  Soybean___healthy
#  Squash___Powdery_mildew
#  Strawberry___healthy
#  Strawberry___Leaf_scorch
#  Tomato___Bacterial_spot
#  Tomato___Early_blight
#  Tomato___healthy
#  Tomato___Late_blight
#  Tomato___Leaf_Mold
#  Tomato___Septoria_leaf_spot
# ...

# %% [markdown]
# In order to extract the Apples dataset I will make a directory and then copy it into my Google Drive. From there I will also download it to my directory in case I want to run the code in Jupyter Notebook later on.

# %%
# !mkdir Apples
# !mkdir Cherry
# !mkdir Corn
# !mkdir Grape
# !mkdir Peach
# !mkdir Pepper
# !mkdir Potato
# !mkdir Strawberry
# !mkdir Tomato

# %%
# Apples -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Apple___Apple_scab" "/content/Apples"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Apple___Black_rot" "/content/Apples"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Apple___Cedar_apple_rust" "/content/Apples"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Apple___healthy" "/content/Apples"

# Cherry -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Cherry_(including_sour)___healthy" "/content/Cherry"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Cherry_(including_sour)___Powdery_mildew" "/content/Cherry"

# Corn -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot" "/content/corn"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Corn_(maize)___Common_rust_" "/content/corn"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Corn_(maize)___healthy" "/content/corn"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Corn_(maize)___Northern_Leaf_Blight" "/content/corn"

# grape -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Grape___Black_rot" "/content/grape"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Grape___Esca_(Black_Measles)" "/content/grape"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/ Grape___healthy" "/content/grape"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)" "/content/grape"

# peach -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Peach___Bacterial_spot" "/content/peach"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Peach___healthy" "/content/peach"

# pepper -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Pepper,_bell___Bacterial_spot" "/content/pepper"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Pepper,_bell___healthy" "/content/pepper"

# potato -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Potato___Early_blight" "/content/potato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Potato___healthy" "/content/potato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Potato___Late_blight" "/content/potato"

# strawberry -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Strawberry___healthy" "/content/strawberry"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Strawberry___Leaf_scorch" "/content/strawberry"

# tomato -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Bacterial_spot" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Early_blight" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___healthy" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Leaf_Mold" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Septoria_leaf_spot" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Tomato___Spider_mites Two-spotted_spider_mite" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Target_Spot" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Tomato_mosaic_virus" "/content/tomato"
# !cp -r "/content/plantvillage-dataset/plantvillage dataset/color/Tomato___Tomato_Yellow_Leaf_Curl_Virus" "/content/tomato"

# %%
# !mv /content/Apples "/content/drive/MyDrive/Potatoes disease proyect/dataset/Apples"
# !mv /content/cherry "/content/drive/MyDrive/Potatoes disease proyect/dataset/cherry"
# !mv /content/corn "/content/drive/MyDrive/Potatoes disease proyect/dataset/corn"
# !mv /content/grape "/content/drive/MyDrive/Potatoes disease proyect/dataset/grape"
# !mv /content/peach "/content/drive/MyDrive/Potatoes disease proyect/dataset/peach"
# !mv /content/pepper "/content/drive/MyDrive/Potatoes disease proyect/dataset/pepper"
# !mv /content/potato "/content/drive/MyDrive/Potatoes disease proyect/dataset/potato"
# !mv /content/strawberry "/content/drive/MyDrive/Potatoes disease proyect/dataset/strawberry"
# !mv /content/tomato "/content/drive/MyDrive/Potatoes disease proyect/dataset/tomato"
# Out:
# mv: cannot stat '/content/Apples': No such file or directory
# mv: cannot stat '/content/Apples': No such file or directory
# mv: cannot stat '/content/Apples': No such file or directory
# mv: cannot stat '/content/Apples': No such file or directory
# mv: cannot stat '/content/Apples': No such file or directory
